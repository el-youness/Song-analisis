# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv
import re
from tqdm import tqdm

# %%
#logIn to API
client_credentials_manager = SpotifyClientCredentials("87b58a021fd44e488b6e0857f67ef780", "a1817896ac4249758675fccd7cc3e7ff")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

#Open song data database
csvfile = open('songdata.csv', newline='')
data = list(csv.reader(csvfile))

# %%
print(len(data))
print(len(range(1,len(data))))
# Out:
# 57651
# 57650

# %%
#iterates over db and build request using artist name and title
found = set()
not_found = set()
#for i in tqdm(range(1,len(data)-1)):
for i in range(15000,15010):
    artist = data[i][0]
    title = data[i][1]
    songsearch = artist + ' ' +  title

    #send request
    results = sp.search(q=songsearch, type='track', limit=1)
    try:
        album_res = sp.album(results['tracks']['items'][0]['album']['uri'])
        print(album_res)
        print(album_res['genres'])
        #search for year only
    except IndexError as e:
        ...
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'}, 'href': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq', 'id': '4AK6F7OLvEQ5QYCBNiQWHq', 'name': 'One Direction', 'type': 'artist', 'uri': 'spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq'}], 'available_markets': ['US'], 'copyrights': [{'text': '(P) 2011 Simco Limited under exclusive licence to Sony Music Entertainment UK Limited', 'type': 'P'}], 'external_ids': {'upc': '886443399013'}, 'external_urls': {'spotify': 'https://open.spotify.com/album/7qfrZ8W7EbA3Hm5TqrkMtX'}, 'genres': [], 'href': 'https://api.spotify.com/v1/albums/7qfrZ8W7EbA3Hm5TqrkMtX', 'id': '7qfrZ8W7EbA3Hm5TqrkMtX', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/0a97d4806b2b258be24ea2b8309a287075d71bbe', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/37545f980a85f788065f8efd9bc9ca9da795ab6e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/0299eb694b
# ...

# %%
print(len(data))
print(len(found)+len(not_found))
# Out:
# 57651
# 57647

# %%
with open('found.csv', 'w', newline='') as csvfile:
    infoWriter = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_MINIMAL)
    infoWriter.writerow(['artist', 'title', 'date'])
    for x in found:
        infoWriter.writerow(x)

# %%
with open('notFound.csv', 'w', newline='') as csvfile:
    infoWriter2 = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_MINIMAL)
    infoWriter2.writerow(['artist', 'title'])
    for y in not_found:
        infoWriter2.writerow(y)
